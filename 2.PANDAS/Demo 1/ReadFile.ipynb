# %%
import pandas as pd


df = pd.read_csv("Stock.csv")
df
# Out:
#   tickers            eps revenue people
# 0    Tata          66.22     677    dev
# 1     DDt           8.33      22    ram
# 2     KVR             -1     455    sam
# 3     MIT  Not Available     122    roy
# 4      HL           5.77      na    jay

# %%
dr = pd.read_csv("Stock.csv",header=None,names=["ticket","eps","revenue","people"])
dr
# Out:
#     ticket            eps  revenue  people
# 0  tickers            eps  revenue  people
# 1     Tata          66.22      677     dev
# 2      DDt           8.33       22     ram
# 3      KVR             -1      455     sam
# 4      MIT  Not Available      122     roy
# 5       HL           5.77       na     jay

# %%
dx = pd.read_csv("Stock.csv",nrows=3)
dx
# Out:
#   tickers    eps  revenue people
# 0    Tata  66.22      677    dev
# 1     DDt   8.33       22    ram
# 2     KVR  -1.00      455    sam

# %%
df.head(4)
# Out:
#   tickers            eps revenue people
# 0    Tata          66.22     677    dev
# 1     DDt           8.33      22    ram
# 2     KVR             -1     455    sam
# 3     MIT  Not Available     122    roy

# %%
df.head()
# Out:
#   tickers            eps revenue people
# 0    Tata          66.22     677    dev
# 1     DDt           8.33      22    ram
# 2     KVR             -1     455    sam
# 3     MIT  Not Available     122    roy
# 4      HL           5.77      na    jay

# %%
df["tickers"]
# Out:
# 0    Tata
# 1     DDt
# 2     KVR
# 3     MIT
# 4      HL
# Name: tickers, dtype: object

# %%
df[df["tickers"]=="Tata"]
# Out:
#   tickers    eps revenue people
# 0    Tata  66.22     677    dev

# %%
df[df["revenue"]!="677"]
# Out:
#   tickers            eps revenue people
# 1     DDt           8.33      22    ram
# 2     KVR             -1     455    sam
# 3     MIT  Not Available     122    roy
# 4      HL           5.77      na    jay

# %%
df[df["eps"]>"10"]
# Out:
#   tickers            eps revenue people
# 0    Tata          66.22     677    dev
# 1     DDt           8.33      22    ram
# 3     MIT  Not Available     122    roy
# 4      HL           5.77      na    jay

# %%
df[3:]
# Out:
#   tickers            eps revenue people
# 3     MIT  Not Available     122    roy
# 4      HL           5.77      na    jay

# %%
df[0:1]
# Out:
#   tickers    eps revenue people
# 0    Tata  66.22     677    dev

# %%
df["tickers"][0:2]
# Out:
# 0    Tata
# 1     DDt
# Name: tickers, dtype: object

# %%
dt = pd.read_excel("Employee.xlsx")
dt
# Out:
#    EmpNo EmpName     Dept  Salary
# 0      1     sam  finance   55567
# 1      2     ram    sales    5434
# 2      3     jay    sales    6565
# 3      4     kay       hr    3535
# 4      5     roy       hr   43344
# 5      6    roop  finance   34343
# 6      7     lil  finance   23322
